# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import pearsonr

# %%
columns = ['Name', 'Age', 'Gender', 'FES score', 'Anxiety Score']
all_scores = pd.read_excel('all_scores.xlsx')[columns]
all_scores
# Out:
#                  Name Age  Gender  FES score  Anxiety Score
# 0    Supriya Chordia   23  Female          0             24
# 1               Pooja  21  Female          0             16
# 2               Sasha  21  Female          0             57
# 3              Krisha  22  Female        211             20
# 4               Manoj  18    Male        213             63
# ..                ...  ..     ...        ...            ...
# 264    Nirmala Baghel  18  Female        204             37
# 265    Nirmala Baghel  18  Female        222             37
# 266     Mahesh paddam  19    Male        207             30
# 267          Lachmani  21  Female        221             45
# 268          Mangali   20  Female        211             48
#
# [269 rows x 5 columns]

# %%
all_scores.boxplot(column=['Anxiety Score', 'FES score'],by='Gender')
# Out:
# array([<Axes: title={'center': 'Anxiety Score'}, xlabel='Gender'>,
#        <Axes: title={'center': 'FES score'}, xlabel='Gender'>],
#       dtype=object)

# %%
all_scores.groupby('Gender').count()
# Out:
#               Name  Age  FES score  Anxiety Score
# Gender
# Female         174  174        174            174
# Male            93   93         93             93
# Third Gender     2    2          2              2

# %%
all_scores_m = all_scores[all_scores['Gender'] == 'Male']
all_scores_f = all_scores[all_scores['Gender'] == 'Female']

def outlier_removal(df):
  numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
  newdf = df.select_dtypes(include=numerics)

  for x in newdf:
      q3,q1 = np.percentile(df.loc[:,x],[75,25])
      iqr = q3-q1

      max = q3+1.5*iqr
      min = q1-1.5*iqr

      newdf.loc[newdf[x] < min,x] = np.nan
      newdf.loc[newdf[x] > max,x] = np.nan

  return newdf.dropna(axis='rows')

all_scores_m_outlier = outlier_removal(all_scores_m)
all_scores_f_outlier = outlier_removal(all_scores_f)
all_scores_outlier = pd.concat([all_scores_m_outlier, all_scores_f_outlier],ignore_index=True)

# %%
all_scores_outlier
# Out:
#      FES score  Anxiety Score
# 0        229.0            9.0
# 1        252.0           11.0
# 2        221.0            1.0
# 3        253.0           29.0
# 4        216.0           37.0
# ..         ...            ...
# 217      236.0           37.0
# 218      204.0           37.0
# 219      222.0           37.0
# 220      221.0           45.0
# 221      211.0           48.0
#
# [222 rows x 2 columns]

# %%
def calculate_corelation(df):
  return pd.DataFrame(pearsonr(df['FES score'],df['Anxiety Score'])).T.rename({0: 'Correlation', 1: 'P-value'},axis=1)

def correlations(dfm, dff, dfcomb):
  return calculate_corelation(dfm), calculate_corelation(dff), calculate_corelation(dfcomb)

# %%
print(correlations(all_scores_m_outlier, all_scores_f_outlier, all_scores_outlier)[0])
# Out:
#    Correlation   P-value
# 0     0.074364  0.501409

# %%
sample_size = 100
for i in range(20):
  print(i)
  sample_male = all_scores_m_outlier.sample(n=sample_size, random_state=i)
  sample_female = all_scores_f_outlier.sample(n=sample_size, random_state=i)
  sample_all = pd.concat([sample_male, sample_female],ignore_index=True)
  corrs = correlations(sample_male, sample_female, sample_all)
  # print(corrs[0])
  # print(corrs[1])
  print(corrs[2])
  print('-----------------------------------------------------------------------------------------')
# Out:
# 0
#    Correlation   P-value
# 0    -0.018632  0.839932
# -----------------------------------------------------------------------------------------
# 1
#    Correlation   P-value
# 0    -0.036102  0.695456
# -----------------------------------------------------------------------------------------
# 2
#    Correlation  P-value
# 0     0.043464  0.63738
# -----------------------------------------------------------------------------------------
# 3
#    Correlation   P-value
# 0     0.040159  0.663208
# -----------------------------------------------------------------------------------------
# 4
#    Correlation   P-value
# 0     0.087429  0.342348
# -----------------------------------------------------------------------------------------
# 5
#    Correlation   P-value
# 0     0.069086  0.453393
# -----------------------------------------------------------------------------------------
# 6
#    Correlation   P-value
# 0    -0.144242  0.116001
# ...
